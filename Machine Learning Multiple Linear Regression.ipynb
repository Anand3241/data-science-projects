# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df=pd.read_csv('Advertising.csv')

# %%
x=df[['TV','radio','newspaper']]

# %%
y=df[['sales']]

# %%
plt.plot(x,y,'bo')

# %%
df.plot(kind='line',layout=(3,3),subplots=True,sharex=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AC99C335F8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AC99E01198>]], dtype=object)

# %%
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.3,random_state=101)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
c=lr.intercept_

# %%
b1=lr.coef_
b1[0][2]
# Out:
# -0.0014720964475761721

# %%
prediction=lr.predict(x_test)

# %%
plt.scatter(y_test,prediction)

# %%
plt.plot(y_test,prediction)

# %%
sns.distplot((y_test-prediction),bins=30)

# %%
reg_line=[(b1[0][0]*TV)+(b1[0][1]*radio)+(b1[0][2]*newspaper) for TV,radio,newspaper in df[['TV','radio','newspaper']]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-043ac7f6ed15> in <module>()
# ----> 1 reg_line=[(b1[0][0]*TV)+(b1[0][1]*radio)+(b1[0][2]*newspaper) for TV,radio,newspaper in df[['TV','radio','newspaper']]]
#
# <ipython-input-58-043ac7f6ed15> in <listcomp>(.0)
# ----> 1 reg_line=[(b1[0][0]*TV)+(b1[0][1]*radio)+(b1[0][2]*newspaper) for TV,radio,newspaper in df[['TV','radio','newspaper']]]
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
x
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# 5      8.7   48.9       75.0
# 6     57.5   32.8       23.5
# 7    120.2   19.6       11.6
# 8      8.6    2.1        1.0
# 9    199.8    2.6       21.2
# 10    66.1    5.8       24.2
# 11   214.7   24.0        4.0
# 12    23.8   35.1       65.9
# 13    97.5    7.6        7.2
# 14   204.1   32.9       46.0
# 15   195.4   47.7       52.9
# 16    67.8   36.6      114.0
# 17   281.4   39.6       55.8
# 18    69.2   20.5       18.3
# 19   147.3   23.9       19.1
# 20   218.4   27.7       53.4
# 21   237.4    5.1       23.5
# 22    13.2   15.9       49.6
# 23   228.3   16.9       26.2
# 24    62.3   12.6       18.3
# 25   262.9    3.5       19.5
# 26   142.9   29.3       12.6
# 27   240.1   16.7       22.9
# 28   248.8   27.1       22.9
# 29    70.6   16.0       40.8
# ..     ...    ...        ...
# ...
